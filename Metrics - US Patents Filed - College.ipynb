# %% [markdown]
# ### Downloading Python libraries

# %%
# !pip install numpy
# !pip install pandas
# !pip install XlsxWriter
# !pip install seaborn

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cm = sns.light_palette("lightgreen", as_cmap=True)

# %% [markdown]
# ### Add your file name (with extension) here

# %%
filename="Metrics - US Patents Filed - College.csv"

# %% [markdown]
# ### Reading the file

# %%
df=pd.read_csv(filename)

# %%
df.head()
# Out:
#         Track Code UIC Track Code Application Number Filing Date  \
# 0  UIC-2020-006-03            NaN         17/305,713  2021-07-13
# 1  UIC-2020-034-03            NaN  PCT/US2021/041677  2021-07-14
# 2  UIC-2008-061-25            NaN         17/375,585  2021-07-14
# 3  UIC-2019-056-03            NaN         17/423,729  2021-07-16
# 4  UIC-2021-146-01            NaN         63/224,115  2021-07-21
#
#            College
# 0     UIC/Pharmacy
# 1  UIC/Engineering
# 2     UIC/Medicine
# 3     UIC/Medicine
# 4     UIC/Pharmacy

# %% [markdown]
# ### Finding Uniques

# %%
df['rank_Track_Code_dups'] = df.groupby('Track Code')['Track Code'].rank(method='first')

# %%
df.style.background_gradient(cmap=cm, subset=pd.IndexSlice[:, ['rank_Track_Code_dups']])
# Out:
# <style type="text/css">
# #T_66198_row0_col5, #T_66198_row1_col5, #T_66198_row2_col5, #T_66198_row3_col5, #T_66198_row4_col5, #T_66198_row5_col5, #T_66198_row6_col5, #T_66198_row7_col5, #T_66198_row8_col5, #T_66198_row10_col5, #T_66198_row11_col5, #T_66198_row12_col5, #T_66198_row13_col5, #T_66198_row14_col5, #T_66198_row15_col5, #T_66198_row16_col5, #T_66198_row17_col5, #T_66198_row18_col5, #T_66198_row19_col5, #T_66198_row21_col5, #T_66198_row22_col5, #T_66198_row23_col5, #T_66198_row24_col5, #T_66198_row25_col5, #T_66198_row26_col5, #T_66198_row27_col5, #T_66198_row28_col5, #T_66198_row29_col5, #T_66198_row30_col5, #T_66198_row31_col5, #T_66198_row32_col5, #T_66198_row33_col5, #T_66198_row34_col5, #T_66198_row35_col5, #T_66198_row36_col5, #T_66198_row37_col5, #T_66198_row38_col5, #T_66198_row40_col5, #T_66198_row41_col5, #T_66198_row42_col5, #T_66198_row43_col5, #T_66198_row44_col5, #T_66198_row45_col5, #T_66198_row46_col5, #T_66198_row48_col5, #T_66198_row49_col5, #T_66198_row51_col5, #T_66198_row52_col5, #T_66198_row53_col5, #T_66198_row54_col5, #T_66198_row55_col5, #T_66198_row59_col5, #T_66198_row60_col5, #T_66198_row61_col5, #T_66198_row64_col5, #T_66198_row65_col5, #T_66198_row66_col5, #T_66198_row67_col5, #T_66198_row68_col5, #T_66198_row69_col5, #T_66198_row70_col5, #T_66198_row71_col5, #T_66198_row72_col5, #T_66198_row73_col5, #T_66198_row74_col5, #T_66198_row76_col5, #T_66198_row77_col5, #T_66198_row78_col5, #T_66198_row79_col5, #T_66198_row80_col5, #T_66198_row81_col5, #T_66198_row82_col5, #T_66198_row83_col5, #T_66198_row84_col5, #T_66198_row86_col5, #T_66198_row87_col5, #T_66198_row88_col5, #T_66198_row89_col5, #T_66198_row90_col5, #T_66198_row92_col5, #T_66198_row93_col5, #T_66198_row94_col5, #T_66198_row95_col5, #T_66198_row96_col5, #T_66198_row97_col5, #T_66198_row98_col5, #T_66198_row99_col5, #T_66198_row100_col5, #T_66198_row101_col5, #T_66198_row102_col5, #T_66198_row104_col5, #T_66198_row105_col5, #T_66198_row106_col5, #T_66198_row107_col5, #T_66198_row108_col5, #T_66198_row109_col5, #T_66198_row114_col5, #T_66198_row115_col5, #T_66198_row116_col5, #T_66198_row117_col5, #T_66198_row118_col5, #T_66198_row119_col5, #T_66198_row120_col5, #T_66198_row123_col5, #T_66198_row124_col5, #T_66198_row125_col5, #T_66198_row126_col5, #T_66198_row127_col5 {
#   background-color: #edf2ed;
#   color: #000000;
# }
# #T_66198_row9_col5, #T_66198_row20_col5, #T_66198_row39_col5, #T_66198_row47_col5, #T_66198_row50_col5, #T_66198_row56_col5, #T_66198_row62_col5, #T_66198_row75_col5, #T_66198_row85_col5, #T_66198_row91_col5, #T_66198_row103_col5, #T_66198_row110_col5, #T_66198_row121_col5 {
#   background-color: #d6f1d6;
#   color: #000000;
# }
# #T_66198_row57_col5, #T_66198_row63_col5, #T_66198_row111_col5, #T_66198_row122_col5 {
#   background-color: #bef0be;
#   color: #000000;
# }
# #T_66198_row58_col5, #T_66198_row112_col5 {
#   background-color: #a7efa7;
#   color: #000000;
# }
# #T_66198_row113_col5 {
#   background-color: #90ee90;
#   color: #000000;
# }
# </style>
# <table id="T_66198_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Track Code</th>
#       <th class="col_heading level0 col1" >UIC Track Code</th>
#       <th class="col_heading level0 col2" >Application Number</th>
#       <th class="col_heading level0 col3" >Filing Date</th>
#       <th class="col_heading level0 col4" >College</th>
#       <th class="col_heading level0 col5" >rank_Track_Code_dups</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66198_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66198_row0_col0" class="data row0 col0" >UIC-2020-006-03</td>
#       <td id="T_66198_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_66198_row0_col2" class="data row0 col2" >17/305,713</td>
#       <td id="T_66198_row0_col3" class="data row0 col3" >2021-07-13</td>
#       <td id="T_66198_row0_col4" class="data row0 col4" >UIC/Pharmacy</td>
#       <td id="T_66198_row0_col5" class="data row0 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66198_row1_col0" class="data row1 col0" >UIC-2020-034-03</td>
#       <td id="T_66198_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_66198_row1_col2" class="data row1 col2" >PCT/US2021/041677</td>
#       <td id="T_66198_row1_col3" class="data row1 col3" >2021-07-14</td>
#       <td id="T_66198_row1_col4" class="data row1 col4" >UIC/Engineering</td>
#       <td id="T_66198_row1_col5" class="data row1 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66198_row2_col0" class="data row2 col0" >UIC-2008-061-25</td>
#       <td id="T_66198_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_66198_row2_col2" class="data row2 col2" >17/375,585</td>
#       <td id="T_66198_row2_col3" class="data row2 col3" >2021-07-14</td>
#       <td id="T_66198_row2_col4" class="data row2 col4" >UIC/Medicine</td>
#       <td id="T_66198_row2_col5" class="data row2 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66198_row3_col0" class="data row3 col0" >UIC-2019-056-03</td>
#       <td id="T_66198_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_66198_row3_col2" class="data row3 col2" >17/423,729</td>
#       <td id="T_66198_row3_col3" class="data row3 col3" >2021-07-16</td>
#       <td id="T_66198_row3_col4" class="data row3 col4" >UIC/Medicine</td>
#       <td id="T_66198_row3_col5" class="data row3 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66198_row4_col0" class="data row4 col0" >UIC-2021-146-01</td>
#       <td id="T_66198_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_66198_row4_col2" class="data row4 col2" >63/224,115</td>
#       <td id="T_66198_row4_col3" class="data row4 col3" >2021-07-21</td>
#       <td id="T_66198_row4_col4" class="data row4 col4" >UIC/Pharmacy</td>
#       <td id="T_66198_row4_col5" class="data row4 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_66198_row5_col0" class="data row5 col0" >UIC-2021-004-02</td>
#       <td id="T_66198_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_66198_row5_col2" class="data row5 col2" >PCT/US2021/042686</td>
#       <td id="T_66198_row5_col3" class="data row5 col3" >2021-07-22</td>
#       <td id="T_66198_row5_col4" class="data row5 col4" >UIC/Medicine</td>
#       <td id="T_66198_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_66198_row6_col0" class="data row6 col0" >UIC-2016-048-35</td>
#       <td id="T_66198_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_66198_row6_col2" class="data row6 col2" >17/385,748</td>
#       <td id="T_66198_row6_col3" class="data row6 col3" >2021-07-26</td>
#       <td id="T_66198_row6_col4" class="data row6 col4" >UIC/Pharmacy</td>
#       <td id="T_66198_row6_col5" class="data row6 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_66198_row7_col0" class="data row7 col0" >UIC-2022-001-01</td>
#       <td id="T_66198_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_66198_row7_col2" class="data row7 col2" >63/203,878</td>
#       <td id="T_66198_row7_col3" class="data row7 col3" >2021-08-03</td>
#       <td id="T_66198_row7_col4" class="data row7 col4" >UIC/Medicine</td>
#       <td id="T_66198_row7_col5" class="data row7 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66198_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_66198_row8_col0" class="data row8 col0" >UIC-2019-068-03</td>
#       <td id="T_66198_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_66198_row8_col2" cla

# %%
unique_records = df[df['rank_Track_Code_dups']==1.000000]

# %%
unique_records.drop('rank_Track_Code_dups', axis=1, inplace=True)
# Out:
# C:\Users\Harsh Jain\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
unique_records.head()
# Out:
#         Track Code UIC Track Code Application Number Filing Date  \
# 0  UIC-2020-006-03            NaN         17/305,713  2021-07-13
# 1  UIC-2020-034-03            NaN  PCT/US2021/041677  2021-07-14
# 2  UIC-2008-061-25            NaN         17/375,585  2021-07-14
# 3  UIC-2019-056-03            NaN         17/423,729  2021-07-16
# 4  UIC-2021-146-01            NaN         63/224,115  2021-07-21
#
#            College
# 0     UIC/Pharmacy
# 1  UIC/Engineering
# 2     UIC/Medicine
# 3     UIC/Medicine
# 4     UIC/Pharmacy

# %%
unique_records.shape
# Out:
# (108, 5)

# %%
df.shape
# Out:
# (128, 6)

# %%
unique_records['Track Code'].nunique()
# Out:
# 108

# %%
df['Track Code'].nunique()
# Out:
# 108

# %% [markdown]
# ### Creating Pivot Table

# %%
table = pd.DataFrame(pd.pivot_table(data=df,index=['College'],values=['Track Code'],aggfunc='count'))
table.reset_index(inplace=True)
table.rename(columns={'Track Code':'#Track_Codes'}, inplace=True)
table
# OR
# df.groupby(['College'])['Invention'].count()
# Out:
#                          College  #Track_Codes
# 0                    Engineering             4
# 1  UIC/Architecture and the Arts             2
# 2                UIC/Engineering            36
# 3          UIC/Innovation Center             2
# 4     UIC/Liberal Arts & Science             4
# 5                   UIC/Medicine            56
# 6            UIC/Medicine/Peoria             1
# 7          UIC/Medicine/Rockford             3
# 8                    UIC/Nursing             1
# 9                   UIC/Pharmacy            18

# %% [markdown]
# ### Data Transformation for Final Report

# %%
colleges = ['Central Administration','Graduate College','Litigation Reserve','President Research Fund','UIC OTM',
            'UIC/Academic Affairs','UIC/Admin.-Dept.','UIC/Applied Health Sciences','UIC/Architecture and the Arts',
            'UIC/Business Administration','UIC/Center for Advance Design, Research and Exploration (CADRE)',
            'UIC/Center for Clinical and Translational Science (CCTS)','UIC/Chancellor','UIC/Dentistry','UIC/Education',
            'UIC/Engineering','UIC/Hospital','UIC/Innovation Center','UIC/Liberal Arts & Science','UIC/Nursing',
            'UIC/OVCR-UIC Research, Office of the Vice Chancellor','UIC/Pharmacy','UIC/Public Health','UIC/Social Work',
            'UIC/UIC School of Law (fka John Marshall Law School)','UIC/Urban Planning & Public Affairs',
            'UIC/Vice Chancellor for Student Affairs','Vice Chancellor for Student Affairs (UIC)','WCA','Engineering',
            'UIC/Medicine','UIC/Medicine/Rockford','UIC/Ophthalmology and Visual Science','UIC/Medicine/Peoria','(blank)']

# %%
listofzeros = [0] * 35

# %%
dummy=pd.DataFrame({'College':colleges,'#Track_Codes':listofzeros})
dummy
# Out:
#                                               College  #Track_Codes
# 0                              Central Administration             0
# 1                                    Graduate College             0
# 2                                  Litigation Reserve             0
# 3                             President Research Fund             0
# 4                                             UIC OTM             0
# 5                                UIC/Academic Affairs             0
# 6                                    UIC/Admin.-Dept.             0
# 7                         UIC/Applied Health Sciences             0
# 8                       UIC/Architecture and the Arts             0
# 9                         UIC/Business Administration             0
# 10  UIC/Center for Advance Design, Research and Ex...             0
# 11  UIC/Center for Clinical and Translational Scie...             0
# 12                                     UIC/Chancellor             0
# 13                                      UIC/Dentistry             0
# 14                                      UIC/Education             0
# 15                                    UIC/Engineering             0
# 16                                       UIC/Hospital             0
# 17                              UIC/Innovation Center             0
# 18                         UIC/Liberal Arts & Science             0
# 19                                        UIC/Nursing             0
# 20  UIC/OVCR-UIC Research, Office of the Vice Chan...             0
# 21                                       UIC/Pharmacy             0
# 22                                  UIC/Public Health             0
# 23                                    UIC/Social Work             0
# 24  UIC/UIC School of Law (fka John Marshall Law S...             0
# 25                UIC/Urban Planning & Public Affairs             0
# 26            UIC/Vice Chancellor for Student Affairs             0
# 27          Vice Chancellor for Student Affairs (UIC)             0
# 28                                                WCA             0
# 29                                        Engineering             0
# 30                                       UIC/Medicine             0
# 31                              UIC/Medicine/Rockford             0
# 32               UIC/Ophthalmology and Visual Science             0
# 33                                UIC/Medicine/Peoria             0
# 34                                            (blank)             0

# %%
ff=pd.concat([table, dummy], axis=0, ignore_index=True)
ff=ff.groupby(['College'])['#Track_Codes'].sum()
ff=pd.DataFrame(ff)
ff.reset_index(inplace=True)
ff
# Out:
#                                               College  #Track_Codes
# 0                                             (blank)             0
# 1                              Central Administration             0
# 2                                         Engineering             4
# 3                                    Graduate College             0
# 4                                  Litigation Reserve             0
# 5                             President Research Fund             0
# 6                                             UIC OTM             0
# 7                                UIC/Academic Affairs             0
# 8                                    UIC/Admin.-Dept.             0
# 9                         UIC/Applied Health Sciences             0
# 10                      UIC/Architecture and the Arts             2
# 11                        UIC/Business Administration             0
# 12  UIC/Center for Advance Design, Research and Ex...             0
# 13  UIC/Center for Clinical and Translational Scie...             0
# 14                                     UIC/Chancellor             0
# 15                                      UIC/Dentistry             0
# 16                                      UIC/Education             0
# 17                                    UIC/Engineering            36
# 18                                       UIC/Hospital             0
# 19                              UIC/Innovation Center             2
# 20                         UIC/Liberal Arts & Science             4
# 21                                       UIC/Medicine            56
# 22                                UIC/Medicine/Peoria             1
# 23                              UIC/Medicine/Rockford             3
# 24                                        UIC/Nursing             1
# 25  UIC/OVCR-UIC Research, Office of the Vice Chan...             0
# 26               UIC/Ophthalmology and Visual Science             0
# 27                                       UIC/Pharmacy            18
# 28                                  UIC/Public Health             0
# 29                                    UIC/Social Work             0
# 30  UIC/UIC School of Law (fka John Marshall Law S...             0
# 31                UIC/Urban Planning & Public Affairs             0
# 32            UIC/Vice Chancellor for Student Affairs             0
# 33          Vice Chancellor for Student Affairs (UIC)             0
# 34                                                WCA             0

# %%
ff['College']=ff['College'].map({'UIC/Medicine': 'Medicine (UIC, Rockford, Peoria, UIHealth)', 
                     'UIC/Medicine/Rockford': 'Medicine (UIC, Rockford, Peoria, UIHealth)',
                     'UIC/Medicine/Peoria':'Medicine (UIC, Rockford, Peoria, UIHealth)',
                     'UIC/Hospital': 'Medicine (UIC, Rockford, Peoria, UIHealth)',
                     'UIC/Applied Health Sciences':'Applied Heath Sciences',
                     'UIC/Architecture and the Arts':'Architecture and the Arts',
                     'UIC/Business Administration':'Business',
                     'UIC/Dentistry':'Dentistry',
                     'UIC/Education':'Education',
                     'UIC/Engineering':'Engineering',
                     'Engineering':'Engineering',
                     'UIC/Innovation Center':'Innovation Center',
                     'UIC/UIC School of Law (fka John Marshall Law School)':'Law',
                     'UIC/Liberal Arts & Science':'Liberal Arts & Science',
                     'UIC/Nursing':'Nursing',
                     'UIC/Pharmacy':'Pharmacy',
                     'UIC/Public Health':'Public Health',
                     'UIC/Social Work':'Social Work',
                     'UIC/Center for Clinical and Translational Science (CCTS)':'Center for Clinical and Translational Sciences (CCTS)',
                     'UIC/Vice Chancellor for Student Affairs':'OVCR-UIC Research, Office of the Vice Chancellor',
                     'Vice Chancellor for Student Affairs (UIC)':'OVCR-UIC Research, Office of the Vice Chancellor',
                     'Central Administration':'Central Administration',
                        'Graduate College':'Graduate College',
                        'Litigation Reserve':'Litigation Reserve',
                        'President Research Fund':'President Research Fund',
                        'UIC OTM':'UIC OTM',
                        'UIC/Academic Affairs':'UIC/Academic Affairs',
                        'UIC/Admin.-Dept.':'UIC/Admin.-Dept.',
                        'UIC/Center for Advance Design, Research and Exploration (CADRE)':'UIC/Center for Advance Design, Research and Exploration (CADRE)',
                        'UIC/Chancellor':'UIC/Chancellor',
                        'UIC/OVCR-UIC Research, Office of the Vice Chancellor':'UIC/OVCR-UIC Research, Office of the Vice Chancellor',
                        'UIC/Urban Planning & Public Affairs':'UIC/Urban Planning & Public Affairs',
                        'WCA':'WCA',
                        'UIC/Ophthalmology and Visual Science':'UIC/Ophthalmology and Visual Science',
                        '(blank)':'(blank)'
})
ff
# Out:
#                                               College  #Track_Codes
# 0                                             (blank)             0
# 1                              Central Administration             0
# 2                                         Engineering             4
# 3                                    Graduate College             0
# 4                                  Litigation Reserve             0
# 5                             President Research Fund             0
# 6                                             UIC OTM             0
# 7                                UIC/Academic Affairs             0
# 8                                    UIC/Admin.-Dept.             0
# 9                              Applied Heath Sciences             0
# 10                          Architecture and the Arts             2
# 11                                           Business             0
# 12  UIC/Center for Advance Design, Research and Ex...             0
# 13  Center for Clinical and Translational Sciences...             0
# 14                                     UIC/Chancellor             0
# 15                                          Dentistry             0
# 16                                          Education             0
# 17                                        Engineering            36
# 18         Medicine (UIC, Rockford, Peoria, UIHealth)             0
# 19                                  Innovation Center             2
# 20                             Liberal Arts & Science             4
# 21         Medicine (UIC, Rockford, Peoria, UIHealth)            56
# 22         Medicine (UIC, Rockford, Peoria, UIHealth)             1
# 23         Medicine (UIC, Rockford, Peoria, UIHealth)             3
# 24                                            Nursing             1
# 25  UIC/OVCR-UIC Research, Office of the Vice Chan...             0
# 26               UIC/Ophthalmology and Visual Science             0
# 27                                           Pharmacy            18
# 28                                      Public Health             0
# 29                                        Social Work             0
# 30                                                Law             0
# 31                UIC/Urban Planning & Public Affairs             0
# 32   OVCR-UIC Research, Office of the Vice Chancellor             0
# 33   OVCR-UIC Research, Office of the Vice Chancellor             0
# 34                                                WCA             0

# %%
ff=ff.groupby(['College'])['#Track_Codes'].sum()
ff=pd.DataFrame(ff)
ff.reset_index(inplace=True)
ff
# Out:
#                                               College  #Track_Codes
# 0                                             (blank)             0
# 1                              Applied Heath Sciences             0
# 2                           Architecture and the Arts             2
# 3                                            Business             0
# 4   Center for Clinical and Translational Sciences...             0
# 5                              Central Administration             0
# 6                                           Dentistry             0
# 7                                           Education             0
# 8                                         Engineering            40
# 9                                    Graduate College             0
# 10                                  Innovation Center             2
# 11                                                Law             0
# 12                             Liberal Arts & Science             4
# 13                                 Litigation Reserve             0
# 14         Medicine (UIC, Rockford, Peoria, UIHealth)            60
# 15                                            Nursing             1
# 16   OVCR-UIC Research, Office of the Vice Chancellor             0
# 17                                           Pharmacy            18
# 18                            President Research Fund             0
# 19                                      Public Health             0
# 20                                        Social Work             0
# 21                                            UIC OTM             0
# 22                               UIC/Academic Affairs             0
# 23                                   UIC/Admin.-Dept.             0
# 24  UIC/Center for Advance Design, Research and Ex...             0
# 25                                     UIC/Chancellor             0
# 26  UIC/OVCR-UIC Research, Office of the Vice Chan...             0
# 27               UIC/Ophthalmology and Visual Science             0
# 28                UIC/Urban Planning & Public Affairs             0
# 29                                                WCA             0

# %%
ff_filtered=ff[~ff['College'].isin(['Central Administration','Graduate College','Litigation Reserve',
                            'President Research Fund','UIC OTM','UIC/Academic Affairs','UIC/Admin.-Dept.',
                            'UIC/Center for Advance Design, Research and Exploration (CADRE)','UIC/Chancellor',
                            'UIC/OVCR-UIC Research, Office of the Vice Chancellor','UIC/Urban Planning & Public Affairs',
                            'WCA','UIC/Ophthalmology and Visual Science'
                           ])]
ff_filtered=ff_filtered.loc[~((ff_filtered['College']=='(blank)') & (ff_filtered['#Track_Codes']==0))]
ff_filtered.reset_index(drop=True, inplace=True)
ff_filtered
# Out:
#                                               College  #Track_Codes
# 0                              Applied Heath Sciences             0
# 1                           Architecture and the Arts             2
# 2                                            Business             0
# 3   Center for Clinical and Translational Sciences...             0
# 4                                           Dentistry             0
# 5                                           Education             0
# 6                                         Engineering            40
# 7                                   Innovation Center             2
# 8                                                 Law             0
# 9                              Liberal Arts & Science             4
# 10         Medicine (UIC, Rockford, Peoria, UIHealth)            60
# 11                                            Nursing             1
# 12   OVCR-UIC Research, Office of the Vice Chancellor             0
# 13                                           Pharmacy            18
# 14                                      Public Health             0
# 15                                        Social Work             0

# %%
ff_filtered.shape[0]
# Out:
# 16

# %%
total=ff_filtered['#Track_Codes'].sum()

# %%
ff_filtered.loc[len(ff_filtered.index)] = ['Total', total] 
ff_filtered
# Out:
#                                               College  #Track_Codes
# 0                              Applied Heath Sciences             0
# 1                           Architecture and the Arts             2
# 2                                            Business             0
# 3   Center for Clinical and Translational Sciences...             0
# 4                                           Dentistry             0
# 5                                           Education             0
# 6                                         Engineering            40
# 7                                   Innovation Center             2
# 8                                                 Law             0
# 9                              Liberal Arts & Science             4
# 10         Medicine (UIC, Rockford, Peoria, UIHealth)            60
# 11                                            Nursing             1
# 12   OVCR-UIC Research, Office of the Vice Chancellor             0
# 13                                           Pharmacy            18
# 14                                      Public Health             0
# 15                                        Social Work             0
# 16                                              Total           127

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('Output_'+filename[:-4]+'.xlsx', engine='xlsxwriter')

# Write each dataframe to a different worksheet. you could write different string like above if you want
df.to_excel(writer, sheet_name='Dataset', index=False)
unique_records.to_excel(writer, sheet_name='Unique', index=False)
ff_filtered.to_excel(writer, sheet_name='Final_Report', index=False)

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# ### Your file has been saved as Output_(filename)

# %% [markdown]
# # Thank You
#   --  Harsh Jain
